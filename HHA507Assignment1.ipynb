# %% [markdown]
# <a href="https://colab.research.google.com/github/nimratmann/datasci_1_loading/blob/main/HHA507Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Loading Packages

# %%
import pandas as pd
# !pip freeze > packages.txt

# %% [markdown]
# #CSV datasets

# %% [markdown]
# ## Description of cancer file: This data contains the Cancer rates by U.S. State

# %%
cancer_rate = pd.read_csv('uscs_map_death_all.csv')
cancer_rate.head(10)
# Out:
#   State           Range   Rate
# 0    AK  164.2 to 174.4  173.1
# 1    AL  174.5 to 199.3  182.1
# 2    AR  174.5 to 199.3  189.6
# 3    AZ  127.9 to 155.3  146.4
# 4    CA  127.9 to 155.3  146.6
# 5    CO  127.9 to 155.3  139.2
# 6    CT  127.9 to 155.3  147.8
# 7    DC  174.5 to 199.3  177.7
# 8    DE  164.2 to 174.4  167.1
# 9    FL  127.9 to 155.3  154.9

# %% [markdown]
# ## Description of drug spending file: This data contains the amounts US spends on prescription drugs

# %%
drug_spending = pd.read_csv('health-medicare-drug-spending.csv')
drug_spending.head(10)
# Out:
#    year brand_name              generic_name coverage_type  total_spending  \
# 0  2010    Abilify              Aripiprazole        Part D    1.225885e+09
# 1  2011    Abilify              Aripiprazole        Part D    1.469590e+09
# 2  2012    Abilify              Aripiprazole        Part D    1.758054e+09
# 3  2013    Abilify              Aripiprazole        Part D    2.107092e+09
# 4  2014    Abilify              Aripiprazole        Part D    2.527319e+09
# 5  2015    Abilify              Aripiprazole        Part D    1.572428e+09
# 6  2010   Abraxane  Paclitaxel Protein-Bound        Part B    1.155539e+08
# 7  2011   Abraxane  Paclitaxel Protein-Bound        Part B    1.213891e+08
# 8  2012   Abraxane  Paclitaxel Protein-Bound        Part B    1.341285e+08
# 9  2013   Abraxane  Paclitaxel Protein-Bound        Part B    2.130076e+08
#
#    beneficiary_count  unit_count  beneficiary_cost_share  \
# 0             338626    71848190             38186677.97
# ...

# %% [markdown]
# # XLSX datasets

# %% [markdown]
# ## Description of obesity prevalence: This data contains obesity prevalence in age groups 6-17 and 18-24 by sex and race/ethnicity, 1999-2000 through 2011-2012

# %%
obesity_prevalence = pd.read_excel('MBK_ObesityPrevalence_Age6-17_Age18-24.xlsx')
obesity_prevalence.head(10)
# Out:
#   Percentage of obese children ages 6–17 by sex and race/ethnicity, 1999–2000 through 2011–2012  \
# 0                                     Characteristic
# 1                                              Total
# 2                                                Sex
# 3                                               Male
# 4                                             Female
# 5                                    Race/ethnicity1
# 6                                White, non-Hispanic
# 7                                Black, non-Hispanic
# 8                                Asian, non-Hispanic
# 9                                           Hispanic
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0  1999–2000  2001–2002  2003–2004  2005–2006  2007–2008  2009–2010  2011–2012
# 1         15      16.52      17.99      16.52       19.2      17.99      20.83
# 2        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %% [markdown]
# ## Description of hospital inputs/outputs data: This data contains the inputs and outputs of hospitals in Kerman province. In this data set, there are 3 inputs and 2 outputs for 4 years.

# %%
hospital = pd.read_excel('hospital-inputs-outputs-Kerman province.xlsx')
hospital.head(10)
# Out:
#    Unnamed: 0 Hospital  Bed occupancy rate  \
# 0         NaN        a               76.22
# 1         NaN        b               67.87
# 2         NaN        c               52.27
# 3         NaN        d               81.04
# 4         NaN        e               32.01
# 5         NaN        f               66.73
# 6         NaN        g               67.81
# 7         NaN        h               37.13
# 8         NaN        i               41.41
# 9         NaN        j               38.86
#
#    Inpatient admission adjusted with stay length  Physician  Nurse  \
# 0                                        92933.4         15    258
# 1                                        86731.7         26    357
# 2                                        56565.7         22    283
# 3                                        70434.0          3    101
# 4                                        32032.8         20     98
# 5                                        27754.1         12     77
# ...

# %% [markdown]
# ## Description of UV county data: This data contains the UV Radiation Exposure by County in Alabama state

# %%
UV_exposure = pd.read_excel('UV County data for Continental US.xlsx')
UV_exposure.head(10)
# Out:
#   STATENAME STATE_ABR  COUNTY_FIPS COUNTY NAME  UV_ Wh/m²
# 0   Alabama        AL         1001     Autauga    4562.75
# 1   Alabama        AL         1003     Baldwin    4492.24
# 2   Alabama        AL         1005     Barbour    4642.21
# 3   Alabama        AL         1007        Bibb    4498.72
# 4   Alabama        AL         1009      Blount    4416.44
# 5   Alabama        AL         1011     Bullock    4628.59
# 6   Alabama        AL         1013      Butler    4579.11
# 7   Alabama        AL         1015     Calhoun    4466.23
# 8   Alabama        AL         1017    Chambers    4583.98
# 9   Alabama        AL         1019    Cherokee    4419.13

# %% [markdown]
# #JSON datasets

# %% [markdown]
# ## Description of Medicare inpatient hospitals data: This data contaisn the Medicare Inpatient Hospitals by Provider and Service dataset provides information on inpatient discharges for Original Medicare Part A beneficiaries by IPPS hospitals. It includes information on the use, payment, and hospital charges for more than 3,000 U.S. hospitals that received IPPS payments. The data are organized by hospital and Medicare Severity Diagnosis Related Group (DRG).

# %%
medicare_inpatient = pd.read_json('https://raw.githubusercontent.com/nimratmann/datasci_1_loading/main/data/Access%20API%20for%20Medicare%20Inpatient%20Hospitals%20-%20by%20Provider%20and%20Service.json')
medicare_inpatient.head(10)
# Out:
#    Rndrng_Prvdr_CCN            Rndrng_Prvdr_Org_Name Rndrng_Prvdr_City  \
# 0             10001  Southeast Health Medical Center            Dothan
# 1             10001  Southeast Health Medical Center            Dothan
# 2             10001  Southeast Health Medical Center            Dothan
# 3             10001  Southeast Health Medical Center            Dothan
# 4             10001  Southeast Health Medical Center            Dothan
# 5             10001  Southeast Health Medical Center            Dothan
# 6             10001  Southeast Health Medical Center            Dothan
# 7             10001  Southeast Health Medical Center            Dothan
# 8             10001  Southeast Health Medical Center            Dothan
# 9             10001  Southeast Health Medical Center            Dothan
#
#           Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  Rndrng_Prvdr_Zip5  \
# 0  1108 Ross Clark Circle                        1              36301
# ...

# %% [markdown]
# ## Description of Covid-19 nursing home data: This data contaims the Nursing Home COVID-19 data reported by nursing homes to the CDC’s National Healthcare Safety Network (NHSN) Long Term Care Facility (LTCF) COVID-19 Module: Surveillance Reporting Pathways and COVID-19 Vaccinations.

# %%
Covid19_nursing = pd.read_json('https://raw.githubusercontent.com/nimratmann/datasci_1_loading/main/data/Covid-19%20Nursing%20Home%20Data.json')
Covid19_nursing.head(10)
# Out:
#   week_ending  federal_provider_number             provider_name  \
# 0  2020-05-24                    15009  BURNS NURSING HOME, INC.
# 1  2020-05-31                    15009  BURNS NURSING HOME, INC.
# 2  2020-06-07                    15009  BURNS NURSING HOME, INC.
# 3  2020-06-14                    15009  BURNS NURSING HOME, INC.
# 4  2020-06-21                    15009  BURNS NURSING HOME, INC.
# 5  2020-06-28                    15009  BURNS NURSING HOME, INC.
# 6  2020-07-05                    15009  BURNS NURSING HOME, INC.
# 7  2020-07-12                    15009  BURNS NURSING HOME, INC.
# 8  2020-07-19                    15009  BURNS NURSING HOME, INC.
# 9  2020-07-26                    15009  BURNS NURSING HOME, INC.
#
#        provider_address provider_city provider_state  provider_zip_code  \
# 0  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# 1  701 MONROE STREET NW  RUSSELLVILLE             AL              35653
# ...

# %% [markdown]
# ## Description of Medicare post acute care and hospice: This data contains the Medicare Post-Acute Care and Hospice Provider Utilization and Payment Public based on demographic and clinical characteristics of beneficiaries served, professional and paraprofessional service utilization, and payment information at the provider, state, and national levels for each PAC setting (i.e. HHA, hospices, SNF, IRF, and LTCH).

# %%
medicare_acutecare_hospice = pd.read_json('https://raw.githubusercontent.com/nimratmann/datasci_1_loading/main/data/Medicare%20Post-Acute%20Care%20and%20Hospice%20-%20by%20Geography%20%26%20Provider.json')
medicare_acutecare_hospice.head(10)
# Out:
#    YEAR YEAR_TYPE SMRY_CTGRY SRVC_CTGRY        PRVDR_ID      PRVDR_NAME  \
# 0  2020        CY     NATION         HH  NATIONAL TOTAL  NATIONAL TOTAL
# 1  2020        FY     NATION        HOS  NATIONAL TOTAL  NATIONAL TOTAL
# 2  2020        FY     NATION        IRF  NATIONAL TOTAL  NATIONAL TOTAL
# 3  2020        FY     NATION        LTC  NATIONAL TOTAL  NATIONAL TOTAL
# 4  2020        FY     NATION        SNF  NATIONAL TOTAL  NATIONAL TOTAL
# 5  2020        CY      STATE         HH     STATE TOTAL     STATE TOTAL
# 6  2020        CY      STATE         HH     STATE TOTAL     STATE TOTAL
# 7  2020        CY      STATE         HH     STATE TOTAL     STATE TOTAL
# 8  2020        CY      STATE         HH     STATE TOTAL     STATE TOTAL
# 9  2020        CY      STATE         HH     STATE TOTAL     STATE TOTAL
#
#        PRVDR_CITY           STATE       PRVDR_ZIP BENE_DSTNCT_CNT  ...  \
# 0  NATIONAL TOTAL  NATIONAL TOTAL  NATIONAL TOTAL       2,849,234  ...
# ...
